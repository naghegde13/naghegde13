# %%
import pandas as pd
import string
import numpy as np
from cape_dataframes.pandas import dtypes

from diffprivlib.models import LogisticRegression as priv_LR, StandardScaler, DecisionTreeClassifier as priv_DTC
from sklearn.linear_model import LogisticRegression as LR
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv('./Assignment2Dataset-1.csv', header = 0, usecols = lambda x: not x.startswith('Unnamed'))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 60 non-null     object
#  1   Country              60 non-null     object
#  2   SSN                  60 non-null     object
#  3   DOB                  60 non-null     object
#  4   Income               60 non-null     int64
#  5   Sex                  60 non-null     object
#  6   Marital Status       60 non-null     object
#  7   Education            60 non-null     object
#  8   Loan                 60 non-null     object
#  9   House Status         60 non-null     object
#  10  Blood Type           60 non-null     object
#  11  Blood Pressure       60 non-null     object
#  12  Heart Rate           59 non-null     float64
#  13  Oxygen Level         59 non-null     object
#  14  Medical Procedure    59 non-null     object
#  15  Smoking              58 non-null     object
#  16  Alcohol Consumption  58 non-null     object
#  17  Allergies            58 non-null     object
#  18  Vaccinations         58 non-null     object
#  19  Tumor Condition      58 non-null     object
# dtypes: float64(1), int64(1), object(18)
# memory usage: 9.5+ KB

# %%
df.shape
# Out:
# (60, 20)

# %%
df.head()
# Out:
#                Name    Country          SSN        DOB  Income     Sex  \
# 0        John Smith        USA  123-45-6789  7/15/1985   50000    Male
# 1     Emily Johnson     Canada  987-65-4321  12/2/1990   60000  Female
# 2     Michael Davis         UK  456-78-9123  3/20/1978   75000    Male
# 3  Jessica Martinez  Australia  789-12-3456  9/10/1982   40000  Female
# 4    David Thompson        USA  234-56-7890  6/25/1995   35000    Male
#
#   Marital Status            Education Loan House Status Blood Type  \
# 0        Married    Bachelor's Degree  Yes          Own         O+
# 1         Single      Master's Degree   No         Rent         A-
# 2       Divorced  High School Diploma  Yes          Own         B+
# 3        Married   Associate's Degree   No          Own        AB-
# 4         Single         Some College   No         Rent         O-
#
#   Blood Pressure  Heart Rate Oxygen Level  Medical Procedure Smoking  \
# 0         120/80        72.0          98%       Appendectomy      No
# 1         110/70        68.0          96%  Laser Eye Surgery      No
# 2         130/85        75.0          97%        Colonoscopy      No
# 3         115/75        70.0          99%          Mammogram      No
# 4         125/80        68.0          97%    Dental Cleaning     Yes
#
#   Alcohol Consumption  Allergies Vaccinations Tumor Condition
# 0                  No     Pollen          Yes          Normal
# 1                 Yes  Shellfish           No          Normal
# 2                 Yes       Cats          Yes        Abnormal
# 3                  No       Dust           No          Normal
# 4                 Yes    Peanuts          Yes          Normal

# %%
def randomize_values(df, columns):
    alphanumeric_char_list = list((string.ascii_letters + string.digits))
    if type(columns) == str:
        columns = [columns]
    for column in columns:
        df[column] = df[column].apply(lambda x: ''.join(np.random.choice(alphanumeric_char_list, size = 10)))
    return df

# %%
# Name and SSN could not provide value for the model or anaylsis hence we just anonymize it
df = randomize_values(df, ["Name", "SSN"])

# %%
df.head()
# Out:
#          Name    Country         SSN        DOB  Income     Sex  \
# 0  LC6QhRjKT8        USA  MBA7r8vlEZ  7/15/1985   50000    Male
# 1  wCHS1mybsK     Canada  Rt08QDh9qM  12/2/1990   60000  Female
# 2  1vHcOXdkG8         UK  srQyLZtF3L  3/20/1978   75000    Male
# 3  PWteECvtqG  Australia  PqblM15Vy8  9/10/1982   40000  Female
# 4  uSGTiTOIGT        USA  GIMXK2aKsQ  6/25/1995   35000    Male
#
#   Marital Status            Education Loan House Status Blood Type  \
# 0        Married    Bachelor's Degree  Yes          Own         O+
# 1         Single      Master's Degree   No         Rent         A-
# 2       Divorced  High School Diploma  Yes          Own         B+
# 3        Married   Associate's Degree   No          Own        AB-
# 4         Single         Some College   No         Rent         O-
#
#   Blood Pressure  Heart Rate Oxygen Level  Medical Procedure Smoking  \
# 0         120/80        72.0          98%       Appendectomy      No
# 1         110/70        68.0          96%  Laser Eye Surgery      No
# 2         130/85        75.0          97%        Colonoscopy      No
# 3         115/75        70.0          99%          Mammogram      No
# 4         125/80        68.0          97%    Dental Cleaning     Yes
#
#   Alcohol Consumption  Allergies Vaccinations Tumor Condition
# 0                  No     Pollen          Yes          Normal
# 1                 Yes  Shellfish           No          Normal
# 2                 Yes       Cats          Yes        Abnormal
# 3                  No       Dust           No          Normal
# 4                 Yes    Peanuts          Yes          Normal

# %%
from cape_dataframes.pandas.transformations import ReversibleTokenizer, Tokenizer, DateTruncation, \
                                                    DatePerturbation, NumericPerturbation, \
                                                    NumericRounding

# %%
df = pd.concat([
            df.drop(columns = ['Blood Pressure', 'Oxygen Level']), 
            pd.DataFrame(df['Oxygen Level'].str.strip('%').astype(float)),
            df['Blood Pressure'].str.split('/', expand = True)\
                                .replace({"": np.NaN}).astype('float')\
                                .rename(columns = {0 : 'Systolic Pressure', 1 : 'Diastolic Pressure'})
    ],
    axis = 1
)

# %%
df.head()
# Out:
#          Name    Country         SSN        DOB  Income     Sex  \
# 0  LC6QhRjKT8        USA  MBA7r8vlEZ  7/15/1985   50000    Male
# 1  wCHS1mybsK     Canada  Rt08QDh9qM  12/2/1990   60000  Female
# 2  1vHcOXdkG8         UK  srQyLZtF3L  3/20/1978   75000    Male
# 3  PWteECvtqG  Australia  PqblM15Vy8  9/10/1982   40000  Female
# 4  uSGTiTOIGT        USA  GIMXK2aKsQ  6/25/1995   35000    Male
#
#   Marital Status            Education Loan House Status  ... Heart Rate  \
# 0        Married    Bachelor's Degree  Yes          Own  ...       72.0
# 1         Single      Master's Degree   No         Rent  ...       68.0
# 2       Divorced  High School Diploma  Yes          Own  ...       75.0
# 3        Married   Associate's Degree   No          Own  ...       70.0
# 4         Single         Some College   No         Rent  ...       68.0
#
#    Medical Procedure Smoking Alcohol Consumption  Allergies Vaccinations  \
# 0       Appendectomy      No                  No     Pollen          Yes
# 1  Laser Eye Surgery      No                 Yes  Shellfish           No
# 2        Colonoscopy      No                 Yes       Cats          Yes
# 3          Mammogram      No                  No       Dust           No
# 4    Dental Cleaning     Yes                 Yes    Peanuts          Yes
#
#   Tumor Condition Oxygen Level  Systolic Pressure  Diastolic Pressure
# 0          Normal         98.0              120.0                80.0
# 1          Normal         96.0              110.0                70.0
# 2        Abnormal         97.0              130.0                85.0
# 3          Normal         99.0              115.0                75.0
# 4          Normal         97.0              125.0                80.0
#
# [5 rows x 21 columns]

# %%
from cryptography.fernet import Fernet

key = Fernet.generate_key()

# %%
cipher_suite = Fernet(key)

# %%
tokenizer_secret = "".join(np.random.choice(list(string.ascii_letters + string.digits), 32))
with open("Tokenizer_secret", 'w') as f:
    f.write(cipher_suite.encrypt(tokenizer_secret.encode()).decode())

# %%
tokenize_cols = ["Country", "Education", "Marital Status", "Blood Type", "House Status", "Sex", "Loan",
                "Medical Procedure", "Smoking", "Alcohol Consumption", "Allergies", "Vaccinations", "Tumor Condition"]

# %%
cat_imputer_pipe = Pipeline([
    ('Encoder', OrdinalEncoder()),
    ('Categorical Iterative Imputer', IterativeImputer(tol = 0, max_iter = 100))
])

imputed_data = cat_imputer_pipe.fit_transform(df[tokenize_cols])
df[tokenize_cols] = cat_imputer_pipe.steps[0][1].inverse_transform(imputed_data)
# Out:
# /home/ajay/sparknlp/lib/python3.10/site-packages/sklearn/impute/_iterative.py:801: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(

# %%
for col in tokenize_cols:
    tokenizer = ReversibleTokenizer(key = tokenizer_secret)
    df[col] = df[[col]].astype(str).apply(tokenizer).values.flatten()

# %%
df['DOB_year'] = pd.to_datetime(df['DOB']).dt.year.astype(int)

# %%
df = df.drop(columns = ['DOB'])

# %% [markdown]
# Differential Privacy - Add perturbations
# DOB, Income, Heart Rate, Oxygen Level, Systolic Pressure, Diastolic Pressure

# %%
value_ranges_dict = {'Income': -4,
                     'Heart Rate': 0,
                     'Oxygen Level': 0,
                     'Systolic Pressure': -1,
                     'Diastolic Pressure': -1,
                     'DOB_year': -1}

# %%
df[df.select_dtypes(exclude = 'object').columns.tolist()] = df.select_dtypes(exclude = 'object').apply(lambda x: \
                            NumericRounding(dtypes.Float, value_ranges_dict.get(x.name))(x))

# %%
df.head()
# Out:
#          Name                                            Country         SSN  \
# 0  LC6QhRjKT8             3f8e37e3213d80d50a42247caf83c90913d18e  MBA7r8vlEZ
# 1  wCHS1mybsK       f21aad0389f7703fc5f4f5f2458b0a2832286eb507ac  Rt08QDh9qM
# 2  1vHcOXdkG8               a3482a2769de3ea402ddfe0683947fa08b13  srQyLZtF3L
# 3  PWteECvtqG  e36933c8b91a22d0f0c35e812a183976fb683e0799350d...  PqblM15Vy8
# 4  uSGTiTOIGT             3f8e37e3213d80d50a42247caf83c90913d18e  GIMXK2aKsQ
#
#     Income                                           Sex  \
# 0  50000.0      cd9013ca1603146996e2355402b24158557967bf
# 1  60000.0  79c32d745577b42562feb70232c94964743bb96bd7e7
# 2  80000.0      cd9013ca1603146996e2355402b24158557967bf
# 3  40000.0  79c32d745577b42562feb70232c94964743bb96bd7e7
# 4  40000.0      cd9013ca1603146996e2355402b24158557967bf
#
#                                      Marital Status  \
# 0    246d5018ec460bd65a6d5900b596d1391551bc2b00716d
# 4     1cf3850dd5e7623fab43d14a05b27aea5d7ec66362c9ce
#
#                              Vaccinations  \
# 0  e75050be0da8765b5ed48fbbfc8273e968174b
# 1    ce73369d7ec699629297ebc218ee6f8c343f
# 2  e75050be0da8765b5ed48fbbfc8273e968174b
# 3    ce73369d7ec699629297ebc218ee6f8c343f
# 4  e75050be0da8765b5ed48fbbfc8273e968174b
#
#                                     Tumor Condition Oxygen Level  \
# 0      f088b8df5f374f2451488088f99dc4059d1ef9893d45         98.0
# 1      f088b8df5f374f2451488088f99dc4059d1ef9893d45         96.0
# 2  9f541ddd4f9cd6406ec922b269e7a0b29cfa6c4a0e12840a         97.0
# 3      f088b8df5f374f2451488088f99dc4059d1ef9893d45         99.0
# 4      f088b8df5f374f2451488088f99dc4059d1ef9893d45         97.0
#
#    Systolic Pressure  Diastolic Pressure  DOB_year
# 0              120.0                80.0    1980.0
# 1              110.0                70.0    1990.0
# 2              130.0                80.0    1980.0
# 3              120.0                80.0    1980.0
# 4              120.0                80.0    2000.0
#
# [5 rows x 21 columns]

# %%
new_column_names = []
for i in df.columns:
    if i == 'Tumor Condition':
        new_column_names.append(cipher_suite.encrypt("Target".encode()))
        continue
    new_column_names.append(cipher_suite.encrypt(i.encode()))

# %%
df.columns = [i.decode() for i in new_column_names]

# %%
df.head()
# Out:
#   gAAAAABl7QW7E2GLP8YI8Uj-3dxmglubRBk64mfIqLthygRJyAJ33e_3S5rQKAT1JIO6Qrow3GOG5_UCC7zN6sQSrNefosXUhA==  \
# 0                                         LC6QhRjKT8
# 1                                         wCHS1mybsK
# 2                                         1vHcOXdkG8
# 3                                         PWteECvtqG
# 4                                         uSGTiTOIGT
#
#   gAAAAABl7QW7NZ7OnDYyW0Vx_RY6Cgr1N3b_HVEAjI1Qwi9oVrQN7rKg-xwzIzXgzRk0xyHDTgBYdm-1HJIsxjWiDRIE9U-mhA==  \
# 0             3f8e37e3213d80d50a42247caf83c90913d18e
# 1       f21aad0389f7703fc5f4f5f2458b0a2832286eb507ac
# 2               a3482a2769de3ea402ddfe0683947fa08b13
# 3  e36933c8b91a22d0f0c35e812a183976fb683e0799350d...
# 4             3f8e37e3213d80d50a42247caf83c90913d18e
#
#   gAAAAABl7QW75rwHnWKJuKuCqGYkJGXm4A_x1NxsPyaVktNmpZmY5U5KuWX2dFDdURTfm79Po8CZLbsZQ-heSL7M7s-OTUD6eg==  \
# 0                                         MBA7r8vlEZ
# 1                                         Rt08QDh9qM
# 2                                         srQyLZtF3L
# 3                                         PqblM15Vy8
# 4                                         GIMXK2aKsQ
#
#    gAAAAABl7QW7iwpZkuvucN84QRsteBepZYNFlrMkovRA9Op5Gfw4c1Mm99Au6OAJ46UJI-wukG1uvU6SQxM4UFqlBlv97rVO3w==  \
# 0                                            50000.0
# 1                                            60000.0
# 2                                            80000.0
# 3                                            40000.0
# 4                                            40000.0
#
#   gAAAAABl7QW70lEiX76Y1KbV2E4SbsG2fg-3OKzYLUry70v7EYHxCH2y6lBoCZ55lW7KFN8bGZ2FZI_tSRF0p7xXr3EX2gHCQQ==  \
# 3       f088b8df5f374f2451488088f99dc4059d1ef9893d45
# 4       f088b8df5f374f2451488088f99dc4059d1ef9893d45
#
#   gAAAAABl7QW7OJRKPQUB2mCxWQEPy1ztYDsMjQ9ThOuq2lUqnYtx43Ne3q8ftgfFOtgwQMuSpscUeV1euM_ncH-evpPdaZsNIg==  \
# 0                                               98.0
# 1                                               96.0
# 2                                               97.0
# 3                                               99.0
# 4                                               97.0
#
#    gAAAAABl7QW72IcFV95LwzfJOqjeeL-wR18wd-DnesgQSPRf6pn0JfMEUCwZMoW7bC-IFTXQtTPkevFPmrUghaIwDckaWmxmaW3VLQCtOcA_XQIMEy6E1sg=  \
# 0                                              120.0
# 1                                              110.0
# 2                                              130.0
# 3                                              120.0
# 4                                              120.0
#
#    gAAAAABl7QW7Q5J2RFg9PBjIcKhUYwpXG4mZnk1YppLDujkfwyAzuS00WTUhZ80ccG2rBeoNMpfpEsCkWyxkJRdCD9QH4qCI50lxNm3aj9D7hssJ_OhZEGk=  \
# 0                                               80.0
# 1                                               70.0
# 2                                               80.0
# 3                                               80.0
# 4                                               80.0
#
#    gAAAAABl7QW7_vmkWQOT3e5hDM6iOknWw3ES8nyIU6MtostgU4jXg-iUdOhi1zI9yvy1PSTkk8oDa818ipX4klOkKWm_ZA8CPw==
# 0                                             1980.0
# 1                                             1990.0
# 2                                             1980.0
# 3                                             1980.0
# 4                                             2000.0
#
# [5 rows x 21 columns]

# %%
df.to_csv('private_data.csv', index = False)

# %% [markdown]
# This data can be shared without a threat to any privacy

# %% [markdown]
# Employees with the right authorities can use the encryption key to decipher the column names. This can be allowed if necessary

# %%
df = pd.read_csv('private_data.csv')
df.columns = [cipher_suite.decrypt(i).decode() for i in df.columns]

# %%
df.head()
# Out:
#          Name                                            Country         SSN  \
# 0  LC6QhRjKT8             3f8e37e3213d80d50a42247caf83c90913d18e  MBA7r8vlEZ
# 1  wCHS1mybsK       f21aad0389f7703fc5f4f5f2458b0a2832286eb507ac  Rt08QDh9qM
# 2  1vHcOXdkG8               a3482a2769de3ea402ddfe0683947fa08b13  srQyLZtF3L
# 3  PWteECvtqG  e36933c8b91a22d0f0c35e812a183976fb683e0799350d...  PqblM15Vy8
# 4  uSGTiTOIGT             3f8e37e3213d80d50a42247caf83c90913d18e  GIMXK2aKsQ
#
#     Income                                           Sex  \
# 0  50000.0      cd9013ca1603146996e2355402b24158557967bf
# 1  60000.0  79c32d745577b42562feb70232c94964743bb96bd7e7
# 2  80000.0      cd9013ca1603146996e2355402b24158557967bf
# 3  40000.0  79c32d745577b42562feb70232c94964743bb96bd7e7
# 4  40000.0      cd9013ca1603146996e2355402b24158557967bf
#
#                                      Marital Status  \
# 0    246d5018ec460bd65a6d5900b596d1391551bc2b00716d
# 1      aad2f44ecd40ea9574217ddddf5f17a4f4fda990d981
# 2  c52315148645b9e42b5153adc6d8e603bf0412f1bf741f77
# 3    246d5018ec460bd65a6d5900b596d1391551bc2b00716d
# 2  e75050be0da8765b5ed48fbbfc8273e968174b
# 3    ce73369d7ec699629297ebc218ee6f8c343f
# 4  e75050be0da8765b5ed48fbbfc8273e968174b
#
#                                              Target Oxygen Level  \
# 0      f088b8df5f374f2451488088f99dc4059d1ef9893d45         98.0
# 1      f088b8df5f374f2451488088f99dc4059d1ef9893d45         96.0
# 2  9f541ddd4f9cd6406ec922b269e7a0b29cfa6c4a0e12840a         97.0
# 3      f088b8df5f374f2451488088f99dc4059d1ef9893d45         99.0
# 4      f088b8df5f374f2451488088f99dc4059d1ef9893d45         97.0
#
#    Systolic Pressure  Diastolic Pressure  DOB_year
# 0              120.0                80.0    1980.0
# 1              110.0                70.0    1990.0
# 2              130.0                80.0    1980.0
# 3              120.0                80.0    1980.0
# 4              120.0                80.0    2000.0
#
# [5 rows x 21 columns]

# %%
df = df.drop(columns = ['Name', 'SSN'])

# %%
X, Y = df.drop(columns = ['Target']), df['Target']
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.3, stratify = Y, random_state = 1234)

# %%
cat_cols = X_train.select_dtypes("object").columns.tolist()

# %%
column_transformer = ColumnTransformer([
    ('Categorical Encoder', OrdinalEncoder(handle_unknown = "use_encoded_value", unknown_value = -1), cat_cols)
], remainder = 'passthrough')

# %%
sklearn_pipeline = Pipeline([("categorical Encoder", column_transformer), 
                  ("Iterative Imputer", IterativeImputer(random_state = 1234)),
                  ("Scaler", StandardScaler(random_state = 1234)),
                  ("Logistic Regression", DecisionTreeClassifier(random_state = 1234))
                 ])

# %%
sklearn_pipeline.fit(X_train, y_train)
sklearn_pipeline.score(X_test, y_test)
# Out:
# /home/ajay/sparknlp/lib/python3.10/site-packages/diffprivlib/models/standard_scaler.py:217: PrivacyLeakWarning: Bounds parameter hasn't been specified, so falling back to determining bounds from the data.
#  This will result in additional privacy leakage.  To ensure differential privacy with no additional privacy loss, specify `bounds` for each valued returned by np.mean().
#   warnings.warn("Bounds parameter hasn't been specified, so falling back to determining bounds from the "
# 1.0

# %%
diff_private_model = Pipeline([("categorical Encoder", column_transformer), 
                  ("Iterative Imputer", IterativeImputer(random_state = 1234)),
                  ("Scaler", StandardScaler(random_state = 1234)),
                  ("Logistic Regression", priv_DTC(random_state = 1234))
                 ])

# %%
diff_private_model.fit(X_train, y_train)
diff_private_model.score(X_test, y_test)
# Out:
# /home/ajay/sparknlp/lib/python3.10/site-packages/diffprivlib/models/standard_scaler.py:217: PrivacyLeakWarning: Bounds parameter hasn't been specified, so falling back to determining bounds from the data.
#  This will result in additional privacy leakage.  To ensure differential privacy with no additional privacy loss, specify `bounds` for each valued returned by np.mean().
#   warnings.warn("Bounds parameter hasn't been specified, so falling back to determining bounds from the "
# /home/ajay/sparknlp/lib/python3.10/site-packages/diffprivlib/models/forest.py:422: PrivacyLeakWarning: Bounds have not been specified and will be calculated on the data provided. This will result in additional privacy leakage. To ensure differential privacy and no additional privacy leakage, specify bounds for each dimension.
#   warnings.warn("Bounds have not been specified and will be calculated on the data provided. This will "
# /home/ajay/sparknlp/lib/python3.10/site-packages/diffprivlib/models/forest.py:430: PrivacyLeakWarning: Classes have not been specified and will be calculated on the data provided. This will result in additional privacy leakage. To ensure differential privacy and no additional privacy leakage, specify the prediction classes for model.
#   warnings.warn("Classes have not been specified and will be calculated on the data provided. This will "
# 0.9444444444444444
